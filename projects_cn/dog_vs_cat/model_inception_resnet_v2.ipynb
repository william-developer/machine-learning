# %% [markdown]
# <div style='text-align:center;font-size:30px;'>Inception-resnet-v2模型</div>

# %% [markdown]
# **1.数据加载与预处理**
#
# * 目录结构
# * train 训练集图片目录，共25000张图片,下载地址：https://www.kaggle.com/c/dogs-vs-cats/data
# * tf-cat-dog-weight-normal.h5 模型训练完成之后的文件

# %%
import os
import numpy as np
from PIL import Image

#根据图片目录处理图片
#调整图片大小，处理标签数据
def load(path):
    imgs = os.listdir(path)
    data = np.empty((25000,299,299,3),dtype="float32")
    label = np.empty((25000,),dtype="uint8")
    num = len(imgs)
    for i in range(num):
        img = Image.open(os.path.join(path,imgs[i]))
        img = img.resize((299,299))
        arr = np.asarray(img,dtype="float32")
        data[i,:,:,:] = arr
        t=imgs[i].split('.')[0]
        if t=='dog' :
            label[i] =1
        else :
            label[i] =0
    return data,label

# %%
#kaggle上下载图片，解压
data,label=load('train')
print(data.shape,len(label))
print(label.shape,len(label))
# Out:
# ((25000, 299, 299, 3), 25000)
# ((25000,), 25000)

# %% [markdown]
# **2.模型实现**

# %%
from keras.layers import Input, merge, Dropout, Dense, Lambda, Flatten, Activation
from keras.layers.convolutional import MaxPooling2D, Convolution2D, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from keras.preprocessing import image
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils, generic_utils

from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
def stem(input):
    # Input Shape is 299 x 299 x 3
    c = Convolution2D(32, 3, 3, activation='relu', subsample=(2, 2))(input)
    c = Convolution2D(32, 3, 3, activation='relu', )(c)
    c = Convolution2D(64, 3, 3, activation='relu', border_mode='same')(c)

    c1 = MaxPooling2D((3, 3), strides=(2, 2))(c)
    c2 = Convolution2D(96, 3, 3, activation='relu', subsample=(2, 2))(c)

    m = merge([c1, c2], mode='concat', concat_axis=-1)

    c1 = Convolution2D(64, 1, 1, activation='relu', border_mode='same')(m)
    c1 = Convolution2D(96, 3, 3, activation='relu', )(c1)

    c2 = Convolution2D(64, 1, 1, activation='relu', border_mode='same')(m)
    c2 = Convolution2D(64, 7, 1, activation='relu', border_mode='same')(c2)
    c2 = Convolution2D(64, 1, 7, activation='relu', border_mode='same')(c2)
    c2 = Convolution2D(96, 3, 3, activation='relu', border_mode='valid')(c2)

    m2 = merge([c1, c2], mode='concat', concat_axis=-1)

    p1 = MaxPooling2D((3, 3), strides=(2, 2), )(m2)
    p2 = Convolution2D(192, 3, 3, activation='relu', subsample=(2, 2))(m2)

    m3 = merge([p1, p2], mode='concat', concat_axis=-1)
    m3 = BatchNormalization(axis=-1)(m3)
    m3 = Activation('relu')(m3)
    return m3
def inception_resnet_A(input):
    init = input

    ir1 = Convolution2D(32, 1, 1, activation='relu', border_mode='same')(input)

    ir2 = Convolution2D(32, 1, 1, activation='relu', border_mode='same')(input)
    ir2 = Convolution2D(32, 3, 3, activation='relu', border_mode='same')(ir2)

    ir3 = Convolution2D(32, 1, 1, activation='relu', border_mode='same')(input)
    ir3 = Convolution2D(48, 3, 3, activation='relu', border_mode='same')(ir3)
    ir3 = Convolution2D(64, 3, 3, activation='relu', border_mode='same')(ir3)

    ir_merge = merge([ir1, ir2, ir3], concat_axis=-1, mode='concat')

    ir_conv = Convolution2D(384, 1, 1, activation='linear', border_mode='same')(ir_merge)
    ir_conv = Lambda(lambda x: x * 0.1)(ir_conv)

    out = merge([init, ir_conv], mode='sum')
    out = BatchNormalization(axis=-1)(out)
    out = Activation("relu")(out)
    return out
def inception_resnet_B(input):
    init = input

    ir1 = Convolution2D(192, 1, 1, activation='relu', border_mode='same')(input)

    ir2 = Convolution2D(128, 1, 1, activation='relu', border_mode='same')(input)
    ir2 = Convolution2D(160, 1, 7, activation='relu', border_mode='same')(ir2)
    ir2 = Convolution2D(192, 7, 1, activation='relu', border_mode='same')(ir2)

    ir_merge = merge([ir1, ir2], mode='concat', concat_axis=-1)

    ir_conv = Convolution2D(1152, 1, 1, activation='linear', border_mode='same')(ir_merge)
    ir_conv = Lambda(lambda x: x * 0.1)(ir_conv)

    out = merge([init, ir_conv], mode='sum')
    out = BatchNormalization(axis=-1)(out)
    out = Activation("relu")(out)
    return out
def inception_resnet_C(input):
    init = input

    ir1 = Convolution2D(192, 1, 1, activation='relu', border_mode='same')(input)

    ir2 = Convolution2D(192, 1, 1, activation='relu', border_mode='same')(input)
    ir2 = Convolution2D(224, 1, 3, activation='relu', border_mode='same')(ir2)
    ir2 = Convolution2D(256, 3, 1, activation='relu', border_mode='same')(ir2)

    ir_merge = merge([ir1, ir2], mode='concat', concat_axis=-1)

    ir_conv = Convolution2D(2144, 1, 1, activation='linear', border_mode='same')(ir_merge)
    ir_conv = Lambda(lambda x: x * 0.1)(ir_conv)

    out = merge([init, ir_conv], mode='sum')
    out = BatchNormalization(axis=-1)(out)
    out = Activation("relu")(out)
    return out
def reduction_A(input, k=192, l=224, m=256, n=384):
    r1 = MaxPooling2D((3,3), strides=(2,2))(input)

    r2 = Convolution2D(n, 3, 3, activation='relu', subsample=(2,2))(input)

    r3 = Convolution2D(k, 1, 1, activation='relu', border_mode='same')(input)
    r3 = Convolution2D(l, 3, 3, activation='relu', border_mode='same')(r3)
    r3 = Convolution2D(m, 3, 3, activation='relu', subsample=(2,2))(r3)

    m = merge([r1, r2, r3], mode='concat', concat_axis=-1)
    m = BatchNormalization(axis=1)(m)
    m = Activation('relu')(m)
    return m
def reduction_B(input):
    r1 = MaxPooling2D((3,3), strides=(2,2), border_mode='valid')(input)

    r2 = Convolution2D(256, 1, 1, activation='relu', border_mode='same')(input)
    r2 = Convolution2D(384, 3, 3, activation='relu', subsample=(2,2))(r2)

    r3 = Convolution2D(256, 1, 1, activation='relu', border_mode='same')(input)
    r3 = Convolution2D(288, 3, 3, activation='relu', subsample=(2, 2))(r3)

    r4 = Convolution2D(256, 1, 1, activation='relu', border_mode='same')(input)
    r4 = Convolution2D(288, 3, 3, activation='relu', border_mode='same')(r4)
    r4 = Convolution2D(320, 3, 3, activation='relu', subsample=(2, 2))(r4)

    m = merge([r1, r2, r3, r4], concat_axis=-1, mode='concat')
    m = BatchNormalization(axis=-1)(m)
    m = Activation('relu')(m)
    return m
def create_inception_resnet_v2(nb_classes=2):
    init = Input((299, 299, 3))

    x = stem(init)

    for i in range(5):
        x = inception_resnet_A(x)

    x = reduction_A(x, k=256, l=256, m=384, n=384)

    for i in range(10):
        x = inception_resnet_B(x)

    x = reduction_B(x)

    for i in range(5):
        x = inception_resnet_C(x)

    x = AveragePooling2D((8,8))(x)

    x = Dropout(0.8)(x)
    x = Flatten()(x)

    # Output
    out = Dense(output_dim=nb_classes, activation='softmax')(x)

    model = Model(init, output=out, name='Inception-Resnet-v2')
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy"])
    return model
model = create_inception_resnet_v2()
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 299, 299, 3)   0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 149, 149, 32)  896         input_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 147, 147, 32)  9248        convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)  (None, 147, 147, 64)  18496       convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)    (None, 73, 73, 64)    0           convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)  (None, 73, 73, 96)    55392       convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                  (None, 73, 73, 160)   0           maxpooling2d_1[0][0]
#                                                                    convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)  (None, 73, 73, 64)    10304       merge_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)  (None, 73, 73, 64)    28736       convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)  (None, 73, 73, 64)    10304       merge_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)  (None, 73, 73, 64)    28736       convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)  (None, 71, 71, 96)    55392       convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D) (None, 71, 71, 96)    55392       convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                  (None, 71, 71, 192)   0           convolution2d_6[0][0]
#                                                                    convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_2 (MaxPooling2D)    (None, 35, 35, 192)   0           merge_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D) (None, 35, 35, 192)   331968      merge_2[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                  (None, 35, 35, 384)   0           maxpooling2d_2[0][0]
#                                                                    convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_1 (BatchNorma (None, 35, 35, 384)   1536        merge_3[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 35, 35, 384)   0           batchnormalization_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D) (None, 35, 35, 32)    12320       activation_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D) (None, 35, 35, 32)    12320       activation_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D) (None, 35, 35, 48)    13872       convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D) (None, 35, 35, 32)    12320       activation_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D) (None, 35, 35, 32)    9248        convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D) (None, 35, 35, 64)    27712       convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# merge_4 (Merge)                  (None, 35, 35, 128)   0           convolution2d_12[0][0]
#                                                                    convolution2d_14[0][0]
#                                                                    convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D) (None, 35, 35, 384)   49536       merge_4[0][0]
# ____________________________________________________________________________________________________
# lambda_1 (Lambda)                (None, 35, 35, 384)   0           convolution2d_18[0][0]
# ____________________________________________________________________________________________________
# merge_5 (Merge)                  (None, 35, 35, 384)   0           activation_1[0][0]
#                                                                    lambda_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_2 (BatchNorma (None, 35, 35, 384)   1536        merge_5[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 35, 35, 384)   0           batchnormalization_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_22 (Convolution2D) (None, 35, 35, 32)    12320       activation_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_20 (Convolution2D) (None, 35, 35, 32)    12320       activation_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_23 (Convolution2D) (None, 35, 35, 48)    13872       convolution2d_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_19 (Convolution2D) (None, 35, 35, 32)    12320       activation_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_21 (Convolution2D) (None, 35, 35, 32)    9248        convolution2d_20[0][0]
# ____________________________________________________________________________________________________
# convolution2d_24 (Convolution2D) (None, 35, 35, 64)    27712       convolution2d_23[0][0]
# ____________________________________________________________________________________________________
# merge_6 (Merge)                  (None, 35, 35, 128)   0           convolution2d_19[0][0]
#                                                                    convolution2d_21[0][0]
#                                                                    convolution2d_24[0][0]
# ____________________________________________________________________________________________________
# convolution2d_25 (Convolution2D) (None, 35, 35, 384)   49536       merge_6[0][0]
# ____________________________________________________________________________________________________
# lambda_2 (Lambda)                (None, 35, 35, 384)   0           convolution2d_25[0][0]
# ____________________________________________________________________________________________________
# merge_7 (Merge)                  (None, 35, 35, 384)   0           activation_2[0][0]
#                                                                    lambda_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_3 (BatchNorma (None, 35, 35, 384)   1536        merge_7[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 35, 35, 384)   0           batchnormalization_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_29 (Convolution2D) (None, 35, 35, 32)    12320       activation_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_27 (Convolution2D) (None, 35, 35, 32)    12320       activation_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_30 (Convolution2D) (None, 35, 35, 48)    13872       convolution2d_29[0][0]
# ____________________________________________________________________________________________________
# convolution2d_26 (Convolution2D) (None, 35, 35, 32)    12320       activation_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_28 (Convolution2D) (None, 35, 35, 32)    9248        convolution2d_27[0][0]
# ____________________________________________________________________________________________________
# convolution2d_31 (Convolution2D) (None, 35, 35, 64)    27712       convolution2d_30[0][0]
# ____________________________________________________________________________________________________
# merge_8 (Merge)                  (None, 35, 35, 128)   0           convolution2d_26[0][0]
#                                                                    convolution2d_28[0][0]
#                                                                    convolution2d_31[0][0]
# ____________________________________________________________________________________________________
# convolution2d_32 (Convolution2D) (None, 35, 35, 384)   49536       merge_8[0][0]
# ____________________________________________________________________________________________________
# lambda_3 (Lambda)                (None, 35, 35, 384)   0           convolution2d_32[0][0]
# ____________________________________________________________________________________________________
# merge_9 (Merge)                  (None, 35, 35, 384)   0           activation_3[0][0]
#                                                                    lambda_3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_4 (BatchNorma (None, 35, 35, 384)   1536        merge_9[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 35, 35, 384)   0           batchnormalization_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_36 (Convolution2D) (None, 35, 35, 32)    12320       activation_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_34 (Convolution2D) (None, 35, 35, 32)    12320       activation_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_37 (Convolution2D) (None, 35, 35, 48)    13872       convolution2d_36[0][0]
# ____________________________________________________________________________________________________
# convolution2d_33 (Convolution2D) (None, 35, 35, 32)    12320       activation_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_35 (Convolution2D) (None, 35, 35, 32)    9248        convolution2d_34[0][0]
# ____________________________________________________________________________________________________
# convolution2d_38 (Convolution2D) (None, 35, 35, 64)    27712       convolution2d_37[0][0]
# ____________________________________________________________________________________________________
# merge_10 (Merge)                 (None, 35, 35, 128)   0           convolution2d_33[0][0]
#                                                                    convolution2d_35[0][0]
#                                                                    convolution2d_38[0][0]
# ____________________________________________________________________________________________________
# convolution2d_39 (Convolution2D) (None, 35, 35, 384)   49536       merge_10[0][0]
# ____________________________________________________________________________________________________
# lambda_4 (Lambda)                (None, 35, 35, 384)   0           convolution2d_39[0][0]
# ____________________________________________________________________________________________________
# merge_11 (Merge)                 (None, 35, 35, 384)   0           activation_4[0][0]
#                                                                    lambda_4[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_5 (BatchNorma (None, 35, 35, 384)   1536        merge_11[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 35, 35, 384)   0           batchnormalization_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_43 (Convolution2D) (None, 35, 35, 32)    12320       activation_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_41 (Convolution2D) (None, 35, 35, 32)    12320       activation_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_44 (Convolution2D) (None, 35, 35, 48)    13872       convolution2d_43[0][0]
# ____________________________________________________________________________________________________
# convolution2d_40 (Convolution2D) (None, 35, 35, 32)    12320       activation_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_42 (Convolution2D) (None, 35, 35, 32)    9248        convolution2d_41[0][0]
# ____________________________________________________________________________________________________
# convolution2d_45 (Convolution2D) (None, 35, 35, 64)    27712       convolution2d_44[0][0]
# ____________________________________________________________________________________________________
# merge_12 (Merge)                 (None, 35, 35, 128)   0           convolution2d_40[0][0]
#                                                                    convolution2d_42[0][0]
#                                                                    convolution2d_45[0][0]
# ____________________________________________________________________________________________________
# convolution2d_46 (Convolution2D) (None, 35, 35, 384)   49536       merge_12[0][0]
# ____________________________________________________________________________________________________
# lambda_5 (Lambda)                (None, 35, 35, 384)   0           convolution2d_46[0][0]
# ____________________________________________________________________________________________________
# merge_13 (Merge)                 (None, 35, 35, 384)   0           activation_5[0][0]
#                                                                    lambda_5[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_6 (BatchNorma (None, 35, 35, 384)   1536        merge_13[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 35, 35, 384)   0           batchnormalization_6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_48 (Convolution2D) (None, 35, 35, 256)   98560       activation_6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_49 (Convolution2D) (None, 35, 35, 256)   590080      convolution2d_48[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_3 (MaxPooling2D)    (None, 17, 17, 384)   0           activation_6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_47 (Convolution2D) (None, 17, 17, 384)   1327488     activation_6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_50 (Convolution2D) (None, 17, 17, 384)   885120      convolution2d_49[0][0]
# ____________________________________________________________________________________________________
# merge_14 (Merge)                 (None, 17, 17, 1152)  0           maxpooling2d_3[0][0]
#                                                                    convolution2d_47[0][0]
#                                                                    convolution2d_50[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_7 (BatchNorma (None, 17, 17, 1152)  68          merge_14[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 17, 17, 1152)  0           batchnormalization_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_52 (Convolution2D) (None, 17, 17, 128)   147584      activation_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_53 (Convolution2D) (None, 17, 17, 160)   143520      convolution2d_52[0][0]
# ____________________________________________________________________________________________________
# convolution2d_51 (Convolution2D) (None, 17, 17, 192)   221376      activation_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_54 (Convolution2D) (None, 17, 17, 192)   215232      convolution2d_53[0][0]
# ____________________________________________________________________________________________________
# merge_15 (Merge)                 (None, 17, 17, 384)   0           convolution2d_51[0][0]
#                                                                    convolution2d_54[0][0]
# ____________________________________________________________________________________________________
# convolution2d_55 (Convolution2D) (None, 17, 17, 1152)  443520      merge_15[0][0]
# ____________________________________________________________________________________________________
# lambda_6 (Lambda)                (None, 17, 17, 1152)  0           convolution2d_55[0][0]
# ____________________________________________________________________________________________________
# merge_16 (Merge)                 (None, 17, 17, 1152)  0           activation_7[0][0]
#                                                                    lambda_6[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_8 (BatchNorma (None, 17, 17, 1152)  4608        merge_16[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 17, 17, 1152)  0           batchnormalization_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_57 (Convolution2D) (None, 17, 17, 128)   147584      activation_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_58 (Convolution2D) (None, 17, 17, 160)   143520      convolution2d_57[0][0]
# ____________________________________________________________________________________________________
# convolution2d_56 (Convolution2D) (None, 17, 17, 192)   221376      activation_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_59 (Convolution2D) (None, 17, 17, 192)   215232      convolution2d_58[0][0]
# ____________________________________________________________________________________________________
# merge_17 (Merge)                 (None, 17, 17, 384)   0           convolution2d_56[0][0]
#                                                                    convolution2d_59[0][0]
# ____________________________________________________________________________________________________
# convolution2d_60 (Convolution2D) (None, 17, 17, 1152)  443520      merge_17[0][0]
# ____________________________________________________________________________________________________
# lambda_7 (Lambda)                (None, 17, 17, 1152)  0           convolution2d_60[0][0]
# ____________________________________________________________________________________________________
# merge_18 (Merge)                 (None, 17, 17, 1152)  0           activation_8[0][0]
#                                                                    lambda_7[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_9 (BatchNorma (None, 17, 17, 1152)  4608        merge_18[0][0]
# ____________________________________________________________________________________________________
# activation_9 (Activation)        (None, 17, 17, 1152)  0           batchnormalization_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_62 (Convolution2D) (None, 17, 17, 128)   147584      activation_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_63 (Convolution2D) (None, 17, 17, 160)   143520      convolution2d_62[0][0]
# ____________________________________________________________________________________________________
# convolution2d_61 (Convolution2D) (None, 17, 17, 192)   221376      activation_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_64 (Convolution2D) (None, 17, 17, 192)   215232      convolution2d_63[0][0]
# ____________________________________________________________________________________________________
# merge_19 (Merge)                 (None, 17, 17, 384)   0           convolution2d_61[0][0]
#                                                                    convolution2d_64[0][0]
# ____________________________________________________________________________________________________
# convolution2d_65 (Convolution2D) (None, 17, 17, 1152)  443520      merge_19[0][0]
# ____________________________________________________________________________________________________
# lambda_8 (Lambda)                (None, 17, 17, 1152)  0           convolution2d_65[0][0]
# ____________________________________________________________________________________________________
# merge_20 (Merge)                 (None, 17, 17, 1152)  0           activation_9[0][0]
#                                                                    lambda_8[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_10 (BatchNorm (None, 17, 17, 1152)  4608        merge_20[0][0]
# ____________________________________________________________________________________________________
# activation_10 (Activation)       (None, 17, 17, 1152)  0           batchnormalization_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_67 (Convolution2D) (None, 17, 17, 128)   147584      activation_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_68 (Convolution2D) (None, 17, 17, 160)   143520      convolution2d_67[0][0]
# ____________________________________________________________________________________________________
# convolution2d_66 (Convolution2D) (None, 17, 17, 192)   221376      activation_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_69 (Convolution2D) (None, 17, 17, 192)   215232      convolution2d_68[0][0]
# ____________________________________________________________________________________________________
# merge_21 (Merge)                 (None, 17, 17, 384)   0           convolution2d_66[0][0]
#                                                                    convolution2d_69[0][0]
# ____________________________________________________________________________________________________
# convolution2d_70 (Convolution2D) (None, 17, 17, 1152)  443520      merge_21[0][0]
# ____________________________________________________________________________________________________
# lambda_9 (Lambda)                (None, 17, 17, 1152)  0           convolution2d_70[0][0]
# ____________________________________________________________________________________________________
# merge_22 (Merge)                 (None, 17, 17, 1152)  0           activation_10[0][0]
#                                                                    lambda_9[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_11 (BatchNorm (None, 17, 17, 1152)  4608        merge_22[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, 17, 17, 1152)  0           batchnormalization_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_72 (Convolution2D) (None, 17, 17, 128)   147584      activation_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_73 (Convolution2D) (None, 17, 17, 160)   143520      convolution2d_72[0][0]
# ____________________________________________________________________________________________________
# convolution2d_71 (Convolution2D) (None, 17, 17, 192)   221376      activation_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_74 (Convolution2D) (None, 17, 17, 192)   215232      convolution2d_73[0][0]
# ____________________________________________________________________________________________________
# merge_23 (Merge)                 (None, 17, 17, 384)   0           convolution2d_71[0][0]
#                                                                    convolution2d_74[0][0]
# ____________________________________________________________________________________________________
# convolution2d_75 (Convolution2D) (None, 17, 17, 1152)  443520      merge_23[0][0]
# ____________________________________________________________________________________________________
# lambda_10 (Lambda)               (None, 17, 17, 1152)  0           convolution2d_75[0][0]
# ____________________________________________________________________________________________________
# merge_24 (Merge)                 (None, 17, 17, 1152)  0           activation_11[0][0]
#                                                                    lambda_10[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_12 (BatchNorm (None, 17, 17, 1152)  4608        merge_24[0][0]
# ____________________________________________________________________________________________________
# activation_12 (Activation)       (None, 17, 17, 1152)  0           batchnormalization_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_77 (Convolution2D) (None, 17, 17, 128)   147584      activation_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_78 (Convolution2D) (None, 17, 17, 160)   143520      convolution2d_77[0][0]
# ____________________________________________________________________________________________________
# convolution2d_76 (Convolution2D) (None, 17, 17, 192)   221376      activation_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_79 (Convolution2D) (None, 17, 17, 192)   215232      convolution2d_78[0][0]
# ____________________________________________________________________________________________________
# merge_25 (Merge)                 (None, 17, 17, 384)   0           convolution2d_76[0][0]
#                                                                    convolution2d_79[0][0]
# ____________________________________________________________________________________________________
# convolution2d_80 (Convolution2D) (None, 17, 17, 1152)  443520      merge_25[0][0]
# ____________________________________________________________________________________________________
# lambda_11 (Lambda)               (None, 17, 17, 1152)  0           convolution2d_80[0][0]
# ____________________________________________________________________________________________________
# merge_26 (Merge)                 (None, 17, 17, 1152)  0           activation_12[0][0]
#                                                                    lambda_11[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_13 (BatchNorm (None, 17, 17, 1152)  4608        merge_26[0][0]
# ____________________________________________________________________________________________________
# activation_13 (Activation)       (None, 17, 17, 1152)  0           batchnormalization_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_82 (Convolution2D) (None, 17, 17, 128)   147584      activation_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_83 (Convolution2D) (None, 17, 17, 160)   143520      convolution2d_82[0][0]
# ____________________________________________________________________________________________________
# convolution2d_81 (Convolution2D) (None, 17, 17, 192)   221376      activation_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_84 (Convolution2D) (None, 17, 17, 192)   215232      convolution2d_83[0][0]
# ____________________________________________________________________________________________________
# merge_27 (Merge)                 (None, 17, 17, 384)   0           convolution2d_81[0][0]
#                                                                    convolution2d_84[0][0]
# ____________________________________________________________________________________________________
# convolution2d_85 (Convolution2D) (None, 17, 17, 1152)  443520      merge_27[0][0]
# ____________________________________________________________________________________________________
# lambda_12 (Lambda)               (None, 17, 17, 1152)  0           convolution2d_85[0][0]
# ____________________________________________________________________________________________________
# merge_28 (Merge)                 (None, 17, 17, 1152)  0           activation_13[0][0]
#                                                                    lambda_12[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_14 (BatchNorm (None, 17, 17, 1152)  4608        merge_28[0][0]
# ____________________________________________________________________________________________________
# activation_14 (Activation)       (None, 17, 17, 1152)  0           batchnormalization_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_87 (Convolution2D) (None, 17, 17, 128)   147584      activation_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_88 (Convolution2D) (None, 17, 17, 160)   143520      convolution2d_87[0][0]
# ____________________________________________________________________________________________________
# convolution2d_86 (Convolution2D) (None, 17, 17, 192)   221376      activation_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_89 (Convolution2D) (None, 17, 17, 192)   215232      convolution2d_88[0][0]
# ____________________________________________________________________________________________________
# merge_29 (Merge)                 (None, 17, 17, 384)   0           convolution2d_86[0][0]
#                                                                    convolution2d_89[0][0]
# ____________________________________________________________________________________________________
# convolution2d_90 (Convolution2D) (None, 17, 17, 1152)  443520      merge_29[0][0]
# ____________________________________________________________________________________________________
# lambda_13 (Lambda)               (None, 17, 17, 1152)  0           convolution2d_90[0][0]
# ____________________________________________________________________________________________________
# merge_30 (Merge)                 (None, 17, 17, 1152)  0           activation_14[0][0]
#                                                                    lambda_13[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_15 (BatchNorm (None, 17, 17, 1152)  4608        merge_30[0][0]
# ____________________________________________________________________________________________________
# activation_15 (Activation)       (None, 17, 17, 1152)  0           batchnormalization_15[0][0]
# ____________________________________________________________________________________________________
# convolution2d_92 (Convolution2D) (None, 17, 17, 128)   147584      activation_15[0][0]
# ____________________________________________________________________________________________________
# convolution2d_93 (Convolution2D) (None, 17, 17, 160)   143520      convolution2d_92[0][0]
# ____________________________________________________________________________________________________
# convolution2d_91 (Convolution2D) (None, 17, 17, 192)   221376      activation_15[0][0]
# ____________________________________________________________________________________________________
# convolution2d_94 (Convolution2D) (None, 17, 17, 192)   215232      convolution2d_93[0][0]
# ____________________________________________________________________________________________________
# merge_31 (Merge)                 (None, 17, 17, 384)   0           convolution2d_91[0][0]
#                                                                    convolution2d_94[0][0]
# ____________________________________________________________________________________________________
# convolution2d_95 (Convolution2D) (None, 17, 17, 1152)  443520      merge_31[0][0]
# ____________________________________________________________________________________________________
# lambda_14 (Lambda)               (None, 17, 17, 1152)  0           convolution2d_95[0][0]
# ____________________________________________________________________________________________________
# merge_32 (Merge)                 (None, 17, 17, 1152)  0           activation_15[0][0]
#                                                                    lambda_14[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_16 (BatchNorm (None, 17, 17, 1152)  4608        merge_32[0][0]
# ____________________________________________________________________________________________________
# activation_16 (Activation)       (None, 17, 17, 1152)  0           batchnormalization_16[0][0]
# ____________________________________________________________________________________________________
# convolution2d_97 (Convolution2D) (None, 17, 17, 128)   147584      activation_16[0][0]
# ____________________________________________________________________________________________________
# convolution2d_98 (Convolution2D) (None, 17, 17, 160)   143520      convolution2d_97[0][0]
# ____________________________________________________________________________________________________
# convolution2d_96 (Convolution2D) (None, 17, 17, 192)   221376      activation_16[0][0]
# ____________________________________________________________________________________________________
# convolution2d_99 (Convolution2D) (None, 17, 17, 192)   215232      convolution2d_98[0][0]
# ____________________________________________________________________________________________________
# merge_33 (Merge)                 (None, 17, 17, 384)   0           convolution2d_96[0][0]
#                                                                    convolution2d_99[0][0]
# ____________________________________________________________________________________________________
# convolution2d_100 (Convolution2D (None, 17, 17, 1152)  443520      merge_33[0][0]
# ____________________________________________________________________________________________________
# lambda_15 (Lambda)               (None, 17, 17, 1152)  0           convolution2d_100[0][0]
# ____________________________________________________________________________________________________
# merge_34 (Merge)                 (None, 17, 17, 1152)  0           activation_16[0][0]
#                                                                    lambda_15[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_17 (BatchNorm (None, 17, 17, 1152)  4608        merge_34[0][0]
# ____________________________________________________________________________________________________
# activation_17 (Activation)       (None, 17, 17, 1152)  0           batchnormalization_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_105 (Convolution2D (None, 17, 17, 256)   295168      activation_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_101 (Convolution2D (None, 17, 17, 256)   295168      activation_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_103 (Convolution2D (None, 17, 17, 256)   295168      activation_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_106 (Convolution2D (None, 17, 17, 288)   663840      convolution2d_105[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_4 (MaxPooling2D)    (None, 8, 8, 1152)    0           activation_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_102 (Convolution2D (None, 8, 8, 384)     885120      convolution2d_101[0][0]
# ____________________________________________________________________________________________________
# convolution2d_104 (Convolution2D (None, 8, 8, 288)     663840      convolution2d_103[0][0]
# ____________________________________________________________________________________________________
# convolution2d_107 (Convolution2D (None, 8, 8, 320)     829760      convolution2d_106[0][0]
# ____________________________________________________________________________________________________
# merge_35 (Merge)                 (None, 8, 8, 2144)    0           maxpooling2d_4[0][0]
#                                                                    convolution2d_102[0][0]
#                                                                    convolution2d_104[0][0]
#                                                                    convolution2d_107[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_18 (BatchNorm (None, 8, 8, 2144)    8576        merge_35[0][0]
# ____________________________________________________________________________________________________
# activation_18 (Activation)       (None, 8, 8, 2144)    0           batchnormalization_18[0][0]
# ____________________________________________________________________________________________________
# convolution2d_109 (Convolution2D (None, 8, 8, 192)     411840      activation_18[0][0]
# ____________________________________________________________________________________________________
# convolution2d_110 (Convolution2D (None, 8, 8, 224)     129248      convolution2d_109[0][0]
# ____________________________________________________________________________________________________
# convolution2d_108 (Convolution2D (None, 8, 8, 192)     411840      activation_18[0][0]
# ____________________________________________________________________________________________________
# convolution2d_111 (Convolution2D (None, 8, 8, 256)     172288      convolution2d_110[0][0]
# ____________________________________________________________________________________________________
# merge_36 (Merge)                 (None, 8, 8, 448)     0           convolution2d_108[0][0]
#                                                                    convolution2d_111[0][0]
# ____________________________________________________________________________________________________
# convolution2d_112 (Convolution2D (None, 8, 8, 2144)    962656      merge_36[0][0]
# ____________________________________________________________________________________________________
# lambda_16 (Lambda)               (None, 8, 8, 2144)    0           convolution2d_112[0][0]
# ____________________________________________________________________________________________________
# merge_37 (Merge)                 (None, 8, 8, 2144)    0           activation_18[0][0]
#                                                                    lambda_16[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_19 (BatchNorm (None, 8, 8, 2144)    8576        merge_37[0][0]
# ____________________________________________________________________________________________________
# activation_19 (Activation)       (None, 8, 8, 2144)    0           batchnormalization_19[0][0]
# ____________________________________________________________________________________________________
# convolution2d_114 (Convolution2D (None, 8, 8, 192)     411840      activation_19[0][0]
# ____________________________________________________________________________________________________
# convolution2d_115 (Convolution2D (None, 8, 8, 224)     129248      convolution2d_114[0][0]
# ____________________________________________________________________________________________________
# convolution2d_113 (Convolution2D (None, 8, 8, 192)     411840      activation_19[0][0]
# ____________________________________________________________________________________________________
# convolution2d_116 (Convolution2D (None, 8, 8, 256)     172288      convolution2d_115[0][0]
# ____________________________________________________________________________________________________
# merge_38 (Merge)                 (None, 8, 8, 448)     0           convolution2d_113[0][0]
#                                                                    convolution2d_116[0][0]
# ____________________________________________________________________________________________________
# convolution2d_117 (Convolution2D (None, 8, 8, 2144)    962656      merge_38[0][0]
# ____________________________________________________________________________________________________
# lambda_17 (Lambda)               (None, 8, 8, 2144)    0           convolution2d_117[0][0]
# ____________________________________________________________________________________________________
# merge_39 (Merge)                 (None, 8, 8, 2144)    0           activation_19[0][0]
#                                                                    lambda_17[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_20 (BatchNorm (None, 8, 8, 2144)    8576        merge_39[0][0]
# ____________________________________________________________________________________________________
# activation_20 (Activation)       (None, 8, 8, 2144)    0           batchnormalization_20[0][0]
# ____________________________________________________________________________________________________
# convolution2d_119 (Convolution2D (None, 8, 8, 192)     411840      activation_20[0][0]
# ____________________________________________________________________________________________________
# convolution2d_120 (Convolution2D (None, 8, 8, 224)     129248      convolution2d_119[0][0]
# ____________________________________________________________________________________________________
# convolution2d_118 (Convolution2D (None, 8, 8, 192)     411840      activation_20[0][0]
# ____________________________________________________________________________________________________
# convolution2d_121 (Convolution2D (None, 8, 8, 256)     172288      convolution2d_120[0][0]
# ____________________________________________________________________________________________________
# merge_40 (Merge)                 (None, 8, 8, 448)     0           convolution2d_118[0][0]
#                                                                    convolution2d_121[0][0]
# ____________________________________________________________________________________________________
# convolution2d_122 (Convolution2D (None, 8, 8, 2144)    962656      merge_40[0][0]
# ____________________________________________________________________________________________________
# lambda_18 (Lambda)               (None, 8, 8, 2144)    0           convolution2d_122[0][0]
# ____________________________________________________________________________________________________
# merge_41 (Merge)                 (None, 8, 8, 2144)    0           activation_20[0][0]
#                                                                    lambda_18[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_21 (BatchNorm (None, 8, 8, 2144)    8576        merge_41[0][0]
# ____________________________________________________________________________________________________
# activation_21 (Activation)       (None, 8, 8, 2144)    0           batchnormalization_21[0][0]
# ____________________________________________________________________________________________________
# convolution2d_124 (Convolution2D (None, 8, 8, 192)     411840      activation_21[0][0]
# ____________________________________________________________________________________________________
# convolution2d_125 (Convolution2D (None, 8, 8, 224)     129248      convolution2d_124[0][0]
# ____________________________________________________________________________________________________
# convolution2d_123 (Convolution2D (None, 8, 8, 192)     411840      activation_21[0][0]
# ____________________________________________________________________________________________________
# convolution2d_126 (Convolution2D (None, 8, 8, 256)     172288      convolution2d_125[0][0]
# ____________________________________________________________________________________________________
# merge_42 (Merge)                 (None, 8, 8, 448)     0           convolution2d_123[0][0]
#                                                                    convolution2d_126[0][0]
# ____________________________________________________________________________________________________
# convolution2d_127 (Convolution2D (None, 8, 8, 2144)    962656      merge_42[0][0]
# ____________________________________________________________________________________________________
# lambda_19 (Lambda)               (None, 8, 8, 2144)    0           convolution2d_127[0][0]
# ____________________________________________________________________________________________________
# merge_43 (Merge)                 (None, 8, 8, 2144)    0           activation_21[0][0]
#                                                                    lambda_19[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_22 (BatchNorm (None, 8, 8, 2144)    8576        merge_43[0][0]
# ____________________________________________________________________________________________________
# activation_22 (Activation)       (None, 8, 8, 2144)    0           batchnormalization_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_129 (Convolution2D (None, 8, 8, 192)     411840      activation_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_130 (Convolution2D (None, 8, 8, 224)     129248      convolution2d_129[0][0]
# ____________________________________________________________________________________________________
# convolution2d_128 (Convolution2D (None, 8, 8, 192)     411840      activation_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_131 (Convolution2D (None, 8, 8, 256)     172288      convolution2d_130[0][0]
# ____________________________________________________________________________________________________
# merge_44 (Merge)                 (None, 8, 8, 448)     0           convolution2d_128[0][0]
#                                                                    convolution2d_131[0][0]
# ____________________________________________________________________________________________________
# convolution2d_132 (Convolution2D (None, 8, 8, 2144)    962656      merge_44[0][0]
# ____________________________________________________________________________________________________
# lambda_20 (Lambda)               (None, 8, 8, 2144)    0           convolution2d_132[0][0]
# ____________________________________________________________________________________________________
# merge_45 (Merge)                 (None, 8, 8, 2144)    0           activation_22[0][0]
#                                                                    lambda_20[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_23 (BatchNorm (None, 8, 8, 2144)    8576        merge_45[0][0]
# ____________________________________________________________________________________________________
# activation_23 (Activation)       (None, 8, 8, 2144)    0           batchnormalization_23[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_1 (AveragePooli (None, 1, 1, 2144)    0           activation_23[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 1, 1, 2144)    0           averagepooling2d_1[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 2144)          0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 2)             4290        flatten_1[0][0]
# ====================================================================================================
# Total params: 30,383,606
# Trainable params: 30,330,196
# Non-trainable params: 53,410
# ____________________________________________________________________________________________________

# %% [markdown]
# **2.训练模型**

# %%
label=np_utils.to_categorical(label, 2)
#aws p2.xlarge 上训练大约25个小时
#model.fit(data, label, batch_size=32,nb_epoch=10,shuffle=True,verbose=2,validation_split=0.2)
#model.save('tf-cat-dog-weight-normal.h5')

# %% [markdown]
# **3.分类预测**

# %%
dict={'0':'cat','1':'dog'}
model = create_inception_resnet_v2()
model.load_weights('tf-cat-dog-weight-normal.h5')
img_path = 'train/cat.2008.jpg'
img = image.load_img(img_path, target_size=(299, 299))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

preds = model.predict(x)
a=np.argmax(preds)
print(dict[str(a)])
# Out:
# cat
